# %% [markdown]
# # Selenium

# %% [markdown]
# ## Selenium 기초

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# Requirement already satisfied: urllib3 in c:\users\hs\appdata\local\programs\python\python36\lib\site-packages (from selenium) (1.25.9)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# You are using pip version 18.1, however version 20.2b1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from selenium import webdriver

# %% [markdown]
# - Chrome드라이버를 사용할예정임

# %%
browser = webdriver.Chrome('./webdriver/chrome/chromedriver.exe')

# %%
browser.set_window_size(1920, 1280)  # 브라우저 사이즈 지정
browser.implicitly_wait(3) # 크롬 브라우저 내부 대기
browser.get('https://www.naver.com/')

# %%
browser.page_source #페이지 소스
# Out:
# '<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"><head> <meta charset="utf-8" /> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <meta name="viewport" content="width=1190" /> <meta name="apple-mobile-web-app-title" content="NAVER" /> <meta name="robots" content="index,nofollow" /> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" /> <meta property="og:title" content="네이버" /> <meta property="og:url" content="https://www.naver.com/" /> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" /> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" /> <meta name="twitter:card" content="summary" /> <meta name="twitter:title" content="" /> <meta name="twitter:url" content="https://www.naver.com/" /> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" /> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" />  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20200625.css" /> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_200326.css" /> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1" />   <script type="text/javascript" src="https://pm.pstatic.net/dist/lib/nelo.20200617.js" defer="defer"></script> <script>document.domain="naver.com",window.nmain=window.nmain||{},window.nmain.gv=window.nmain.gv||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent;window.nmain.isIE=navigator.appName&amp;&amp;0&lt;navigator.appName.indexOf("Explorer")&amp;&amp;ua.toLocaleLowerCase().indexOf("msie 10.0")&lt;0,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua);var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode</script> <script>window.nmain.isIE&amp;&amp;(Object.create=function(n){function t(){}return t.prototype=n,new t})</script> <script>\nwindow.nmain.newsstand = {\nrcode: \'09680101\',\nnewsCastSubsInfo: \'\',\nnewsStandSubsInfo: \'\'\n};\nwindow.nmain.gv.daInfo = {"ANIMAL":{"menu":"ANIMAL","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000161","singleDomAdUrl":"https://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_1","tb":"ANIMAL_1","unit":"SU10567","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000162","singleDomAdUrl":"https://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_2","tb":"ANIMAL_1","unit":"SU10568","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BUSINESS":{"menu":"BUSINESS","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000165","singleDomAdUrl":"https://nv.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_1","tb":"BUSINESS_1","unit":"SU10577","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000166","singleDomAdUrl":"https://nv.veta.naver.com/fxshow","param":{ ...

# %%
dir(browser)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_cdp_cmd',
#  'execute_script',
#  'file_detector',
#  'file_detector_context',
#  'find_element',
#  'find_element_by_class_name',
#  'find_element_by_css_selector',
#  'find_element_by_id',
#  'find_element_by_link_text',
#  'find_element_by_name',
#  'find_element_by_partial_link_text',
#  'find_element_by_tag_name',
#  'find_element_by_xpath',
#  'find_elements',
#  'find_elements_by_class_name',
#  'find_elements_by_css_selector',
#  'find_elements_by_id',
#  'find_elements_by_link_text',
#  'find_elements_by_name',
#  'find_elements_by_partial_link_text',
#  'find_elements_by_tag_name',
#  'find_elements_by_xpath',
#  'forward',
#  'fullscreen_window',
#  'get',
#  'get_cookie',
#  'get_cookies',
#  'get_log',
#  'get_network_conditions',
#  'get_screenshot_as_base64',
#  'get_screenshot_as_file',
#  'get_screenshot_as_png',
#  'get_window_position',
#  'get_window_rect',
#  'get_window_size',
#  'implicitly_wait',
#  'launch_app',
#  'log_types',
#  'maximize_window',
#  'minimize_window',
#  'mobile',
#  'name',
#  'orientation',
#  'page_source',
#  'quit',
#  'refresh',
#  'save_screenshot',
#  'service',
#  'session_id',
#  'set_network_conditions',
#  'set_page_load_timeout',
#  'set_script_timeout',
#  'set_window_position',
#  'set_window_rect',
#  'set_window_size',
#  'start_client',
#  'start_session',
#  'stop_client',
#  'switch_to',
#  'switch_to_active_element',
#  'switch_to_alert',
#  'switch_to_default_content',
#  'switch_to_frame',
#  'switch_to_window',
#  'title',
#  'w3c',
#  'window_handles']

# %%
print(browser.title)
print(browser.current_url)
print(browser.get_cookies())
# Out:
# NAVER
# https://www.naver.com/
# [{'domain': '.naver.com', 'expiry': 1625212968, 'httpOnly': False, 'name': 'NRTK', 'path': '/', 'secure': False, 'value': 'ag#all_gr#1_ma#-2_si#0_en#0_sp#0'}, {'domain': 'www.naver.com', 'expiry': 1909036967, 'httpOnly': False, 'name': 'NM_THEME_EDIT', 'path': '/', 'secure': False, 'value': ''}, {'domain': '.naver.com', 'expiry': 2524640400.165528, 'httpOnly': False, 'name': 'NNB', 'path': '/', 'secure': True, 'value': 'R5C4MIVIST6V4'}, {'domain': 'www.naver.com', 'expiry': 1593763366.067966, 'httpOnly': True, 'name': 'PM_CK_loc', 'path': '/', 'secure': False, 'value': '4f442a2af035a2c1fcd866e851beed48b90c3186a1525eac9f5ae3c8024a0c4f'}]

# %%
ele = browser.find_element_by_css_selector('div.green_window > input.input_text')

# %%
dir(ele)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_execute',
#  '_id',
#  '_parent',
#  '_upload',
#  '_w3c',
#  'clear',
#  'click',
#  'find_element',
#  'find_element_by_class_name',
#  'find_element_by_css_selector',
#  'find_element_by_id',
#  'find_element_by_link_text',
#  'find_element_by_name',
#  'find_element_by_partial_link_text',
#  'find_element_by_tag_name',
#  'find_element_by_xpath',
#  'find_elements',
#  'find_elements_by_class_name',
#  'find_elements_by_css_selector',
#  'find_elements_by_id',
#  'find_elements_by_link_text',
#  'find_elements_by_name',
#  'find_elements_by_partial_link_text',
#  'find_elements_by_tag_name',
#  'find_elements_by_xpath',
#  'get_attribute',
#  'get_property',
#  'id',
#  'is_displayed',
#  'is_enabled',
#  'is_selected',
#  'location',
#  'location_once_scrolled_into_view',
#  'parent',
#  'rect',
#  'screenshot',
#  'screenshot_as_base64',
#  'screenshot_as_png',
#  'send_keys',
#  'size',
#  'submit',
#  'tag_name',
#  'text',
#  'value_of_css_property']

# %%
ele.send_keys('상명대학교')

# %%
ele.submit()

# %%
browser.save_screenshot("sangmyung.jpg")
# Out:
# d:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py:1031: UserWarning: name used for saved screenshot does not match file type. It should end with a `.png` extension
#   "type. It should end with a `.png` extension", UserWarning)
# True

# %%
browser.quit()

# %%
browser = webdriver.Chrome('./webdriver/chrome/chromedriver.exe')

# %%
browser.get('https://www.naver.com/')

# %%
ele = browser.find_element_by_css_selector('#NM_FAVORITE > div.group_nav > ul.list_nav.type_fix > li:nth-child(2) > a')

# %%
ele.click()

# %%
browser.quit()

# %% [markdown]
# ## Selenium 기본

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
chrome_options = Options()
chrome_options.add_argument("--headless")

# %%
browser = webdriver.Chrome('./webdriver/chrome/chromedriver.exe', options=chrome_options)

# %% [markdown]
# 크롬이 어떻게 동작하고싶은지 보고싶으면 option 제거하면 됨.
#
# 현재 크롬 옵션에 브라우저가 눈으로 보이지 않게 되어있음

# %%
browser.quit()

# %%
browser = webdriver.Chrome('./webdriver/chrome/chromedriver.exe')

# %% [markdown]
# 브라우 대기시간과 사이즈 조정
#
# (참고)
#
# Implicitly wait: 정해진 시간만큼 충분히 기다리기
#
# Explicitly wait: 어떤 조건이 만족할 때까지 기다리기

# %%
browser.implicitly_wait(3)
browser.set_window_size(1920, 1280)

# %%
browser.get('https://search.shopping.naver.com/search/all?where=all&frm=NVSCTAB&query=%EB%84%A4%EC%9D%B4%EB%B2%84%EC%87%BC%ED%95%91')

# %% [markdown]
# 가져온 페이지 소스보기

# %%
browser.page_source
# Out:
# '<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="ko"><head><link rel="preconnect" href="https://static.nid.naver.com" /><link rel="preconnect" href="https://lcs.naver.com" /><link rel="preconnect" href="http://shopping.phinf.naver.net" /><link rel="preconnect" href="https://ssl.pstatic.net" /><link rel="preconnect" href="https://shopping-phinf.pstatic.net" /><link rel="preconnect" href="https://volts.shopping.naver.com" /><meta name="viewport" content="width=device-width" /><meta charset="utf-8" /><title>네이버쇼핑 : 네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/img/favicon.ico" /><meta property="og:title" content="네이버쇼핑 : 네이버 쇼핑" /><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png" /><meta property="og:description" content="\'네이버쇼핑\'의 네이버쇼핑 검색 결과입니다" /><meta name="viewport" content="width=device-width" /><script async="true" src="https://ssl.pstatic.net/tveta/libs/ssp/ssp.web.sdk.js"></script><meta name="next-head-count" content="8" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/18a8dd1dda74e730b411.css" as="style" /><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/18a8dd1dda74e730b411.css" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/4d14c967b3a888bd6cf6.css" as="style" /><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/4d14c967b3a888bd6cf6.css" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/43769d9bdb9234abc366.css" as="style" /><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/43769d9bdb9234abc366.css" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/pcekqTqpJlQ0bWTH2znUz/pages/_app.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/pcekqTqpJlQ0bWTH2znUz/pages/search/all.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/40.a717bd5de0ad07c11ede.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/41.61d29a4f1ecf6b0fee22.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/34.49d4215c7d133300a2f7.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/9.ee3ff56190e86a25e25b.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/35.91e4261305b3096bdedb.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/runtime/webpack-c80adb5429af2e54a671.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/framework.86900b2066d9a41d48b1.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/95344d8ab2c3ba6a4c955e320c56eda821b1e7b9.e966b8b38c7899df693d.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/cb37ee72a303a00d66e5cd53053895cc08dccbfb.3358f83e871a834e2d64.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/729f1f61a309e6082b05710079153539d4d187c2.f5abedc3825ed7baf3f8.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/ccc5f6184fb8aa ...

# %% [markdown]
# 상단 우측 쇼핑연관 더보기 클릭
#
# 크롤링을 할때 양이 많으면 가져오기 전에 코드가 사라지는 경우가 있으므로
#
# class 이름이 relatedTags_btn_more__3Um4x인 요소가 로딩될때까지 3초를 기다리고 해당 요소를 클릭하는 명령어를 실행

# %% [markdown]
# ## (참고)셀렉터가 변하기 때문에 강의를 보고 응용해서 해야할 수 있음

# %%
WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.CSS_SELECTOR, '.relatedTags_btn_more__3Um4x'))).click()

# %% [markdown]
# 40만원 ~ 160만원 제품 필터링 클릭

# %%
WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.CSS_SELECTOR, '#__next > div > div.container > div.style_inner__18zZX > div.filter_finder__1Gtei > div > div:nth-child(3) > div.finder_etc_inner > ul > li:nth-child(4) > button'))).click()

# %% [markdown]
# 무료배송 선택

# %%
WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.CSS_SELECTOR, '#__next > div > div.container > div.style_inner__18zZX > div.filter_finder__1Gtei > div.filter_finder_filter__1DTIN > div:nth-child(4) > div.finder_etc_inner > ul > li:nth-child(1) > button'))).click()

# %%
browser.page_source
# Out:
# '<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="ko"><head><link rel="preconnect" href="https://static.nid.naver.com" /><link rel="preconnect" href="https://lcs.naver.com" /><link rel="preconnect" href="http://shopping.phinf.naver.net" /><link rel="preconnect" href="https://ssl.pstatic.net" /><link rel="preconnect" href="https://shopping-phinf.pstatic.net" /><link rel="preconnect" href="https://volts.shopping.naver.com" /><meta name="viewport" content="width=device-width" /><meta charset="utf-8" /><title>네이버쇼핑 : 네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/img/favicon.ico" /><meta property="og:title" content="네이버쇼핑 : 네이버 쇼핑" /><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png" /><meta property="og:description" content="\'네이버쇼핑\'의 네이버쇼핑 검색 결과입니다" /><meta name="viewport" content="width=device-width" /><script async="true" src="https://ssl.pstatic.net/tveta/libs/ssp/ssp.web.sdk.js"></script><meta name="next-head-count" content="8" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/18a8dd1dda74e730b411.css" as="style" /><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/18a8dd1dda74e730b411.css" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/4d14c967b3a888bd6cf6.css" as="style" /><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/4d14c967b3a888bd6cf6.css" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/43769d9bdb9234abc366.css" as="style" /><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/css/43769d9bdb9234abc366.css" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/pcekqTqpJlQ0bWTH2znUz/pages/_app.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/pcekqTqpJlQ0bWTH2znUz/pages/search/all.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/40.a717bd5de0ad07c11ede.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/41.61d29a4f1ecf6b0fee22.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/34.49d4215c7d133300a2f7.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/9.ee3ff56190e86a25e25b.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/35.91e4261305b3096bdedb.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/runtime/webpack-c80adb5429af2e54a671.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/framework.86900b2066d9a41d48b1.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/95344d8ab2c3ba6a4c955e320c56eda821b1e7b9.e966b8b38c7899df693d.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/cb37ee72a303a00d66e5cd53053895cc08dccbfb.3358f83e871a834e2d64.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/729f1f61a309e6082b05710079153539d4d187c2.f5abedc3825ed7baf3f8.js" as="script" /><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/200701-125208/_next/static/chunks/ccc5f6184fb8aa ...

# %%
soup = BeautifulSoup(browser.page_source, "html.parser")

# %%
len(soup.select('.list_basis > div > div'))
# Out:
# 4

# %%
# title 가져오기

# %%
for ele in soup.select('.list_basis > div > div'):
    print(ele.select_one('.basicList_title__3P9Q7 > a').text)
# Out:
# 네이버 쇼핑 스마트스토어 실전 마스터 교육 12개월 과정
# 리파 프리미엄
# 리파 럭스
# GDMSN-0004 SNS마케팅 기업광고 월150만 2개월 광고시 픽셀 + 프리미엄 반응형 홈페이지 무료제공!

# %% [markdown]
# 40개씩 보기인데 5개인 이유
# - 처음에 rendering시 5개만 불러오고 스크롤을 내릴때마다 5개씩 추가로 가져오기 때문
#
# -  selenium을 통해서 스크롤을 내릴 수 있기 때문에 원한다면 더 많은 정보를 가져올 수 잇음

# %%
#페이지 스크롤 다운
body = browser.find_element_by_css_selector('body')
for i in range(5):
    body.send_keys(Keys.PAGE_DOWN)
    browser.implicitly_wait(3)

# %%
soup = BeautifulSoup(browser.page_source, "html.parser")
len(soup.select('.list_basis > div > div'))
# Out:
# 4

# %%
for ele in soup.select('.list_basis > div > div'):
    print(ele.select_one('.basicList_title__3P9Q7 > a').text)
# Out:
# 네이버 쇼핑 스마트스토어 실전 마스터 교육 12개월 과정
# 리파 프리미엄
# 리파 럭스
# GDMSN-0004 SNS마케팅 기업광고 월150만 2개월 광고시 픽셀 + 프리미엄 반응형 홈페이지 무료제공!

# %%
data_list = []
for ele in soup.select('.list_basis > div > div'):
    _dict={}
    title = ele.select_one('.basicList_title__3P9Q7 > a').text
    price = ele.select_one('.price_num__2WUXn').text
    _dict.update({"title":title,"price":price})
    data_list.append(_dict)

# %%
data_list
# Out:
# [{'title': '네이버 쇼핑 스마트스토어 실전 마스터 교육 12개월 과정', 'price': '2,200,000원'},
#  {'title': '리파 프리미엄', 'price': '1,760,000원'},
#  {'title': '리파 럭스', 'price': '1,760,000원'},
#  {'title': 'GDMSN-0004 SNS마케팅 기업광고 월150만 2개월 광고시 픽셀 + 프리미엄 반응형 홈페이지 무료제공!',
#   'price': '1,650,000원'}]

# %%
browser.quit()

# %% [markdown]
# ### Everytime 로그인

# %%
browser = webdriver.Chrome('./webdriver/chrome/chromedriver.exe')

# %%
browser.get('https://everytime.kr/login')

# %%
ele = browser.find_element_by_css_selector('input[name="userid"]')

# %%
ele.send_keys('hosung22103')

# %%
p_ele = browser.find_element_by_css_selector('input[name="password"]')

# %%
p_ele.send_keys('')

# %%
submit_ele = browser.find_element_by_css_selector('#container > form > p.submit > input')

# %%
submit_ele.click()

# %% [markdown]
# #### 실시간 인기글 클릭

# %%
hot_ele = browser.find_element_by_css_selector('#container > div.rightside > div:nth-child(2) > div > a:nth-child(3)')

# %%
hot_ele.click()

# %%
soup = BeautifulSoup(browser.page_source, "html.parser")

# %%
post = soup.select_one('#container > .wrap.articles > article > a.article')

# %%
title = post.h2.text

# %%
contents=""
for p in post.select('p'):
    contents += p.text

# %%
title
# Out:
# '브릿지'

# %%
contents
# Out:
# '도망갔네 참 대단하다'

# %%
vote = post.select_one('ul:nth-child(7) > li.vote').text

# %%
comment = post.select_one('ul:nth-child(7) > li.comment').text

# %%
scrap = post.select_one('ul:nth-child(7) > li.scrap').text

# %% [markdown]
# ### 함수화

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
#브라우저 띄우는 함수 

def _browser(headless=False):
    chrome_options = Options()
    if headless is True:
        chrome_options.add_argument("--headless")
    browser = webdriver.Chrome('./webdriver/chrome/chromedriver.exe', options=chrome_options)
    browser.implicitly_wait(3)
    browser.set_window_size(1920, 1280)
    return browser
    
def _get_page(url):
    browser.get(url)
    
def login_evertime(browser, _id,_pw):
    ele = browser.find_element_by_css_selector('input[name="userid"]')
    p_ele = browser.find_element_by_css_selector('input[name="password"]')
    ele.send_keys(_id)
    p_ele.send_keys(_pw)
    submit_ele = browser.find_element_by_css_selector('#container > form > p.submit > input')
    submit_ele.click()
    
def _click_hot_post(browser, first_or_second):
    """
    실시간 인기글은 2가지인데 둘중하나 선택해서 이동 후 html return
    """
    if first_or_second == 'first':
        hot_ele = browser.find_element_by_css_selector('#container > div.rightside > div:nth-child(2) > div > a:nth-child(2)')
    elif first_or_second =='second':
        hot_ele = browser.find_element_by_css_selector('#container > div.rightside > div:nth-child(2) > div > a:nth-child(3)')
    hot_ele.click()
    time.sleep(2)
    return browser.page_source

def data_parser(page_source):
    soup = BeautifulSoup(page_source, "html.parser")
    post = soup.select_one('#container > .wrap.articles > article > a.article')
    title = post.h2.text
    contents=""
    for p in post.select('p'):
        contents += p.text
    vote = post.select_one('ul:nth-child(7) > li.vote').text
    comment = post.select_one('ul:nth-child(7) > li.comment').text
    scrap = post.select_one('ul:nth-child(7) > li.scrap').text
    
    data_dict = {
        "제목":title,
        "내용":contents,
        "공감":vote,
        "댓글수":comment,
        "스크랩수": scrap
                 }
    return data_dict

# %%
def main():
    browser = _browser()
    browser.get('https://everytime.kr/login')
    login_evertime(browser, 'hosung22103', '')
    page_source=_click_hot_post(browser, 'second')
    data_dict = data_parser(page_source)
    print(data_dict)

# %%
main()
# Out:
# {'제목': '얘들아 운체는', '내용': '운영체제 컴과 전공이야 ... 운동과 체육 ... 아니야 ... 교양 ... 아니야 ... 전공이야 ... 내용이 엄청 많구 ... 하루 수업 피피티는 4분할로 뽑으면 두장, 세장인데 강의는 거의 두시간이야... 중간고사 과제 대체로 하셨어 ... 보고서 35장 나왔어 ... 저번주에 제출마감이였는데 ... 내일 기말 시험이야 ... 전범위 ... 돌아버리겠어 ... 눈물나 ... 읽어도 읽어도 모르겠어 ... 내 인생 ... 그럼 이만 ...', '공감': '18', 'comment': '8', 'scrap': '0'}
