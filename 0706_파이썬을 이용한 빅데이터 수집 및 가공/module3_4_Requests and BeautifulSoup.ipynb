# %% [markdown]
# ## Requests and BeautifulSoup

# %% [markdown]
# request로 데이터를 요청후 BeautifulSoup으로 파싱

# %% [markdown]
# - requests 는 urllib.requests같은 역할로 데이터를 요청하고 응답값을 받는 역할을 함
#
# - BeautifulSoup은 html을 받아와서 원하는 정보만 고를 수 있도록 해주는 라이브러리임

# %%
from IPython.display import Image

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.naver.com/')

# %% [markdown]
# requests.get(url)은 크롬창에서 url을 직접 입력한다고 생각하면 됨.

# %%
Image('img/requests_img.png')

# %%
#브라우저 결과
Image('img/requests_img2.png')

# %%
#res = requests.get('https://www.naver.com/') 결과
res.text
# Out:
# '\n<!doctype html>                     <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인
# ...

# %% [markdown]
# 다시말해서 브라우저에 url을 넣는 방식과 똑같음
#
# 단지 응답값을 Chrome은 웹페이지를 보여주는 것이고 파이썬 코드는 html코드를 그대로 받았을 뿐임

# %% [markdown]
# BeautifulSoup을 통해서 원하는 text만 가져오려고함.
#
# BeautifulSoup()에 첫번째 인자로 requests 응답값을 넣고 받은 응답값이 html형식이니 html parser를 선태함

# %%
soup=BeautifulSoup(res.text, 'html.parser')

# %% [markdown]
# 가져온 html에서 원하는 tag에 있는 정보를 가지고 오려고 함.
#
# 기본적인 설명은 밑에 수업내용에 있음. 지금은 참고용 예시

# %%
Image('img/bs.png')

# %% [markdown]
# 원하는 부분 마우스 우클릭 후 Copy > Copy selector 사용하면 요소를 복사할 수 있음

# %%
news = soup.select('.thumb_box._NM_NEWSSTAND_THUMB._NM_NEWSSTAND_THUMB_press_valid')

# %%
news[0].select('a.btn_popup')[2].get('href')
# Out:
# 'http://newsstand.naver.com/?list=&pcode=930'

# %%
news_url_list = []
news = soup.select('.thumb_box._NM_NEWSSTAND_THUMB._NM_NEWSSTAND_THUMB_press_valid')
for n in news:
    url = n.select('a.btn_popup')[2].get('href')
    news_url_list.append(url)

# %%
news_url_list
# Out:
# ['http://newsstand.naver.com/?list=&pcode=930',
#  'http://newsstand.naver.com/?list=&pcode=021',
#  'http://newsstand.naver.com/?list=&pcode=376',
#  'http://newsstand.naver.com/?list=&pcode=028',
#  'http://newsstand.naver.com/?list=&pcode=081',
#  'http://newsstand.naver.com/?list=&pcode=030',
#  'http://newsstand.naver.com/?list=&pcode=006',
#  'http://newsstand.naver.com/?list=&pcode=215',
#  'http://newsstand.naver.com/?list=&pcode=422',
#  'http://newsstand.naver.com/?list=&pcode=047',
#  'http://newsstand.naver.com/?list=&pcode=003',
#  'http://newsstand.naver.com/?list=&pcode=214',
#  'http://newsstand.naver.com/?list=&pcode=005',
#  'http://newsstand.naver.com/?list=&pcode=056',
#  'http://newsstand.naver.com/?list=&pcode=330',
#  'http://newsstand.naver.com/?list=&pcode=361',
#  'http://newsstand.naver.com/?list=&pcode=910',
#  'http://newsstand.naver.com/?list=&pcode=344',
#  'http://newsstand.naver.com/?list=&pcode=374',
#  'http://newsstand.naver.com/?list=&pcode=946',
# ...

# %% [markdown]
# ## request
#
# - 네트워크 통신을 하기 위해 사용하는 기능으로 간편하여 자주 사용된다.
# - 브라우저에서 url을 요청하는 기능과 같다고 생각하면 된다
# - 단지 브라우저 주소창 대신 python 코드로 넣을 뿐이다.
# - requests.get(url, headers= , data= , cookies=)... 의 형식을 띈다
# - url부분에 브라우저에 넣는 url을 입력하면 된다. 나머지는 필수값은 아니다.

# %%
res = requests.get('https://www.python.org/')

# %%
res.text
# Out:
# '<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n\n    <meta name="application-name" content="Python.org">\n    <meta name="msapplication-tooltip" content="The official home of the Python Programming Language">\n    <meta name="apple-mobile-web-app-title" content="Python.org">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="H
# ...

# %%
print(res.status_code)
print(res.ok)
# Out:
# 200
# True

# %% [markdown]
# #### requests 옵션

# %%
headers={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
    'Referer': 'https://www.naver.com/'
}

cookies = {
    'cookies':'sb=dmBgXvzIDrI0p1Rdkydf879q; datr=dmBgXilbqp4jquLVZKIrxswp; _fbp=fb.1.1584092064077.779764559; c_user=100002376155218; xs=36%3ArsvqRdVoBpA-kw%3A2%3A1589416418%3A15385%3A10127; dpr=1.25; spin=r.1002305120_b.trunk_t.1593324023_s.1_v.2_; fr=0Cdm1xUNEZVeU2lRc.AWXc--dXwrf6bdtRyr0rc7_jPi0.BeX29D.qS.F7y.0.0.Be-Dg3.AWVU_EmZ'
}

timeout = 1

verify =False #기본 True -> ssl때문에 오류발생 시

auth = ("ID","PASSWORD") #인증해야할때

# %%
res = requests.get('https://www.python.org/', timeout=0.1)
res
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# d:\python\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# d:\python\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# d:\python\lib\site-packages\urllib3\connection.py in connect(self)
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#
# ...

# %%
res = requests.get('https://www.python.org/', timeout=1)
res.status_code
# Out:
# 200

# %%
res = requests.get('https://www.python.org/',headers=headers)

# %%
res.raise_for_status() #200 코드 아니면 에러발생

# %%
res.text
# Out:
# '<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n\n    <meta name="application-name" content="Python.org">\n    <meta name="msapplication-tooltip" content="The official home of the Python Programming Language">\n    <meta name="apple-mobile-web-app-title" content="Python.org">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="H
# ...

# %%
dir(res)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
res.encoding
# Out:
# 'utf-8'

# %%
res.request
# Out:
# <PreparedRequest [GET]>

# %%
res.apparent_encoding
# Out:
# 'ascii'

# %% [markdown]
# #### BeautifulSoup 기초

# %%
# BeautifulSoup

from bs4 import BeautifulSoup


text = """
<html>
<head>
<title>Ma:deri</title>
</head>
<body>
<h1> maderi h1 </h1>
<h2> maderi h2 </h2>
<p class="title"><b>BeautifulSoup</b></p>
<p class="content">contents
<a href="http://www.maderi.co.kr/" class="m_main" id="maderi">Maderi</a>
<a href="http://datamarketing.co.kr/" class="d_main" id="dmk" val="home">DMK</a>
</p>
<p class="call">call me...</p>
<div>
    <table>
        <thead></thead>
        <tbody>
            <tr>
                <td>철수</td>
                <td>24</td>
            </tr>
            <tr>
                <td>영희</td>
                <td>31</td>
            </tr>
        </tbody>
    </table>
</div>
</body>
</html>
"""

# %%
soup = BeautifulSoup(text, 'html.parser')

# %%
print(soup.prettify()) #코드확인
# Out:
# <html>
#  <head>
#   <title>
#    Ma:deri
#   </title>
#  </head>
#  <body>
#   <h1>
#    maderi h1
#   </h1>
#   <h2>
#    maderi h2
#   </h2>
#   <p class="title">
#    <b>
#     BeautifulSoup
#    </b>
#   </p>
#   <p class="content">
#    contents
#    <a class="m_main" href="http://www.maderi.co.kr/" id="maderi">
#     Maderi
#    </a>
#    <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">
#     DMK
#    </a>
#   </p>
#   <p class="call">
#    call me...
#   </p>
#   <div>
#    <table>
#     <thead>
#     </thead>
#     <tbody>
#      <tr>
#       <td>
#        철수
#       </td>
#       <td>
#        24
#       </td>
#      </tr>
#      <tr>
#       <td>
#        영희
#       </td>
#       <td>
#        31
#       </td>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#  </body>
# </html>

# %% [markdown]
# > body, head 접근

# %%
head = soup.html.head
head
# Out:
# <head>
# <title>Ma:deri</title>
# </head>

# %%
body = soup.html.body
body
# Out:
# <body>
# <h1> maderi h1 </h1>
# <h2> maderi h2 </h2>
# <p class="title"><b>BeautifulSoup</b></p>
# <p class="content">contents
# <a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>
# <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>
# </p>
# <p class="call">call me...</p>
# <div>
# <table>
# <thead></thead>
# <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# </tr>
# </tbody>
# </table>
# </div>
# </body>

# %% [markdown]
# > h1, h2

# %%
h1 = soup.html.body.h1
h2 = soup.html.body.h2.text

# %%
print(h1)
print(h2)
# Out:
# <h1> maderi h1 </h1>
#  maderi h2

# %%
dir(h1)
# Out:
# ['__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'descendants',
#  'encode',
#  'encode_contents',
# ...

# %% [markdown]
# > p 태그

# %%
p =  soup.html.body.p
print(p)
print('----------------------------------------')
p2 = p.next_sibling.next_sibling
print(p2)
print('-------------------------')
print(list(p2.next_elements))
# Out:
# <p class="title"><b>BeautifulSoup</b></p>
# ----------------------------------------
# <p class="content">contents
# <a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>
# <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>
# </p>
# -------------------------
# ['contents\n', <a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>, 'Maderi', '\n', <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>, 'DMK', '\n', '\n', <p class="call">call me...</p>, 'call me...', '\n', <div>
# <table>
# <thead></thead>
# <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# </tr>
# </tbody>
# </table>
# </div>, '\n', <table>
# <thead></thead>
# <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# </tr>
# </tbody>
# </table>, '\n', <thead></thead>, '\n', <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# ...

# %%
from pprint import pprint

# %%
pprint(list(p2.next_elements))
# Out:
# ['contents\n',
#  <a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>,
#  'Maderi',
#  '\n',
#  <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>,
#  'DMK',
#  '\n',
#  '\n',
#  <p class="call">call me...</p>,
#  'call me...',
#  '\n',
#  <div>
# <table>
# <thead></thead>
# <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# </tr>
# </tbody>
# </table>
# </div>,
#  '\n',
#  <table>
# <thead></thead>
# <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# </tr>
# </tbody>
# </table>,
#  '\n',
#  <thead></thead>,
#  '\n',
#  <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# </tr>
# </tbody>,
#  '\n',
#  <tr>
# <td>철수</td>
# <td>24</td>
# </tr>,
#  '\n',
#  <td>철수</td>,
#  '철수',
#  '\n',
#  <td>24</td>,
#  '24',
#  '\n',
#  '\n',
#  <tr>
# <td>영희</td>
# <td>31</td>
# </tr>,
#  '\n',
#  <td>영희</td>,
#  '영희',
#  '\n',
# ...

# %% [markdown]
# #### BeautifulSoup find

# %%
soup
# Out:
# <html>
# <head>
# <title>Ma:deri</title>
# </head>
# <body>
# <h1> maderi h1 </h1>
# <h2> maderi h2 </h2>
# <p class="title"><b>BeautifulSoup</b></p>
# <p class="content">contents
# <a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>
# <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>
# </p>
# <p class="call">call me...</p>
# <div>
# <table>
# <thead></thead>
# <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# </tr>
# </tbody>
# </table>
# </div>
# </body>
# </html>

# %%
a = soup.find_all("a")
pprint(a)
print(a[0].get('href'))
# Out:
# [<a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>,
#  <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>]
# http://www.maderi.co.kr/

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort',
#  'source']

# %%
a2 = soup.find_all("a", class_='m_main')
a2
# Out:
# [<a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>]

# %%
a = soup.find('a')
print(a)
print(a.text)
print(a.get('href'))
# Out:
# <a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>
# Maderi
# http://www.maderi.co.kr/

# %%
a2 = soup.find("a",{"class":"d_main", "val": "home"})
a2
# Out:
# <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>

# %% [markdown]
# BeautifulSoup select

# %%
soup
# Out:
# <html>
# <head>
# <title>Ma:deri</title>
# </head>
# <body>
# <h1> maderi h1 </h1>
# <h2> maderi h2 </h2>
# <p class="title"><b>BeautifulSoup</b></p>
# <p class="content">contents
# <a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>
# <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>
# </p>
# <p class="call">call me...</p>
# <div>
# <table>
# <thead></thead>
# <tbody>
# <tr>
# <td>철수</td>
# <td>24</td>
# </tr>
# <tr>
# <td>영희</td>
# <td>31</td>
# </tr>
# </tbody>
# </table>
# </div>
# </body>
# </html>

# %%
title = soup.select_one("p.title > b")
print(title)
print(title.text)
# Out:
# <b>BeautifulSoup</b>
# BeautifulSoup

# %%
dmk = soup.select("#dmk")[0]
print(dmk)
print(dmk.text)
# Out:
# <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>
# DMK

# %%
dmk2 = soup.select("a[val='home']")[0]
print(dmk2)
print(dmk.text)
# Out:
# <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>
# DMK

# %%
url = soup.select("p.content > a")
url
# Out:
# [<a class="m_main" href="http://www.maderi.co.kr/" id="maderi">Maderi</a>,
#  <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>]

# %%
url2 = soup.select("p.content > a:nth-of-type(2)")[0]
print(url2)
print(url2.get('href'))
# Out:
# <a class="d_main" href="http://datamarketing.co.kr/" id="dmk" val="home">DMK</a>
# http://datamarketing.co.kr/

# %%
call = soup.select("p.call")
call
# Out:
# [<p class="call">call me...</p>]

# %% [markdown]
# ## requests and BeautifulSoup 실습1

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.smu.ac.kr/lounge/qna/faq.do'

# %%
res = requests.get(url)

# %%
res.ok
# Out:
# True

# %%
soup=BeautifulSoup(res.text, 'html.parser')

# %%
table = soup.select('.board-thumb-wrap > li')

# %%
len(table)
# Out:
# 7

# %%
table[0]
# Out:
# <li class="">
# <dl class="board-thumb-content-wrap board-thumb-content-wrap-v01">
# <dt class="board-thumb-content-title">
# <a href="?mode=view&amp;articleNo=698890&amp;article.offset=0&amp;articleLimit=10" style="  " target="" title="Office365(학생메일) 사용법 자세히 보기">
# 						Office365(학생메일) 사용법</a>
# </dt>
# <dd class="board-thumb-content-info">
# <ul>
# <li class="board-thumb-content-writer">
# <span class="hide">작성자</span>
# 							통합 관리자
# 						</li>
# <li class="board-thumb-content-date">
# <span class="hide">작성일</span>
# 							2019-04-03
# 						</li>
# <li class="board-thumb-content-views">
# <span class="hide">조회수</span>
# 							26895
# 						</li>
# </ul>
# </dd>
# </dl>
# <div class="list-file"></div>
# </li>

# %%
title = table[0].select_one('a').text.replace('\r','').replace('\t','').replace('\n','')
table[0].select_one('.board-thumb-content-writer').span.decompose() #자식요소제거
author = table[0].select_one('.board-thumb-content-writer').text.replace('\r','').replace('\t','').replace('\n','')
param = table[0].select_one('a').get('href')

# %%
print(title)
print(author)
print(param)
# Out:
# Office365(학생메일) 사용법
# 통합 관리자
# ?mode=view&articleNo=698890&article.offset=0&articleLimit=10

# %% [markdown]
# #### 세부게시물내용크롤링

# %%
url = 'https://www.smu.ac.kr/lounge/qna/faq.do?mode=view&articleNo=698890&article.offset=0&articleLimit=10'

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="ko">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-129351146-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-129351146-1');
# </script>
# <title>상명라운지 | 상명 Q&amp;A | 자주하는 질문 게시판읽기(Office365(학생메일) 사용법) | 상명라운지</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <link href="https://www.smu.ac.kr:443/lounge/qna/faq.do" rel="canonical"/>
# <link href="https://fonts.googleapis.com/css?family=Cardo" rel="stylesheet"/>
# <link href="/_common/cms.css" rel="stylesheet" type="text/css">
# ...

# %%
soup.select_one('h4').text.replace('\r','').replace('\t','').replace('\n','').replace('  ','')
# Out:
# 'Office365(학생메일) 사용법'

# %%
soup.body.h4.text.replace('\r','').replace('\t','').replace('\n','').replace('  ','')
# Out:
# 'Office365(학생메일) 사용법'

# %%
content = ""
for s in soup.select('.fr-view > .fr-view > p'):
    content += s.text

# %%
content
# Out:
# 'Office365는 계정 비밀번호 연동 후 사용이 가능합니다.Office365(학생메일) 비밀번호 연동 방법1. http://sso.smu.ac.kr:8082\xa0통합로그인 사이트 접속 후 로그인 (오른쪽 퀵메뉴에 통합로그인 클릭해도 접속 가능)2. Office365 버튼 클릭3. 비밀번호 입력창이나오면 통합로그인 패스워드와 동일한 패스워드로 입력4. 패스워드 입력하면 자동으로 학번@sangmyung.kr 로 계정이 연동되며, 이 후 메일이 사용가능합니다.Office 설치형 제품군(pro plus)은 재학생만 사용가능합니다.이외의 기능은 전체 학생이 사용 가능합니다.'

# %% [markdown]
# #### faq전체가져오기!

# %%
url = 'https://www.smu.ac.kr/lounge/qna/faq.do'
res = requests.get(url)
soup=BeautifulSoup(res.text, 'html.parser')

# %%
table = soup.select('.board-thumb-wrap > li')

# %%
table
# Out:
# [<li class="">
#  <dl class="board-thumb-content-wrap board-thumb-content-wrap-v01">
#  <dt class="board-thumb-content-title">
#  <a href="?mode=view&amp;articleNo=698890&amp;article.offset=0&amp;articleLimit=10" style="  " target="" title="Office365(학생메일) 사용법 자세히 보기">
#  						Office365(학생메일) 사용법</a>
#  </dt>
#  <dd class="board-thumb-content-info">
#  <ul>
#  <li class="board-thumb-content-writer">
#  <span class="hide">작성자</span>
#  							통합 관리자
#  						</li>
#  <li class="board-thumb-content-date">
#  <span class="hide">작성일</span>
#  							2019-04-03
#  						</li>
#  <li class="board-thumb-content-views">
#  <span class="hide">조회수</span>
#  							26895
#  						</li>
#  </ul>
#  </dd>
#  </dl>
#  <div class="list-file"></div>
#  </li>, <li class="">
#  <dl class="board-thumb-content-wrap board-thumb-content-wrap-v01">
#  <dt class="board-thumb-content-title">
# ...

# %%
for t in table:
    param = t.select_one('a').get('href')
    base_url = 'https://www.smu.ac.kr/lounge/qna/faq.do?'
    url = base_url+param
    print(url)
# Out:
# https://www.smu.ac.kr/lounge/qna/faq.do??mode=view&articleNo=698890&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do??mode=view&articleNo=684733&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do??mode=view&articleNo=684732&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do??mode=view&articleNo=264776&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do??mode=view&articleNo=264774&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do??mode=view&articleNo=264773&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do??mode=view&articleNo=264772&article.offset=0&articleLimit=10

# %%
result_list=[]
for t in table:
    _dict = {}
    
    param = t.select_one('a').get('href')
    base_url = 'https://www.smu.ac.kr/lounge/qna/faq.do'
    url = base_url+param
    res = requests.get(url)
    print(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    title = soup.select_one('h4').text.replace('\r','').replace('\t','').replace('\n','').replace('  ','')
    content = ""
    for s in soup.select('.fr-view > .fr-view > p'):
        content += s.text
    
    _dict['title']= title
    _dict['content'] = content
    result_list.append(_dict)
# Out:
# https://www.smu.ac.kr/lounge/qna/faq.do?mode=view&articleNo=698890&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do?mode=view&articleNo=684733&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do?mode=view&articleNo=684732&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do?mode=view&articleNo=264776&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do?mode=view&articleNo=264774&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do?mode=view&articleNo=264773&article.offset=0&articleLimit=10
# https://www.smu.ac.kr/lounge/qna/faq.do?mode=view&articleNo=264772&article.offset=0&articleLimit=10

# %%
result_list
# Out:
# [{'title': 'Office365(학생메일) 사용법',
#   'content': 'Office365는 계정 비밀번호 연동 후 사용이 가능합니다.Office365(학생메일) 비밀번호 연동 방법1. http://sso.smu.ac.kr:8082\xa0통합로그인 사이트 접속 후 로그인 (오른쪽 퀵메뉴에 통합로그인 클릭해도 접속 가능)2. Office365 버튼 클릭3. 비밀번호 입력창이나오면 통합로그인 패스워드와 동일한 패스워드로 입력4. 패스워드 입력하면 자동으로 학번@sangmyung.kr 로 계정이 연동되며, 이 후 메일이 사용가능합니다.Office 설치형 제품군(pro plus)은 재학생만 사용가능합니다.이외의 기능은 전체 학생이 사용 가능합니다.'},
#  {'title': '학사)복학 신청을 꼭 해야하나요? 복학은 어떻게 신청하나요?',
#   'content': "휴학 기간이 끝난 후 자동적으로 복학이 되지 않으며, 꼭 아래의 절차를 통해 복학 신청을 해야합니다.만약 휴학 기간이 끝난 후에도 복학을 하지 않으면, 수강신청이 불가하며 추후 미복학제적이 되니 꼭 복학신청을 하시기 바랍니다.복학을 신청하는 방법은 아래와 같습니다.1) 샘물통합정보시스템 로그인2) '학적정보' > '휴학/복학/자퇴/휴학취소신청' > 인적사항 및 복학 정보 입력 > 저장\xa0\xa0(군휴학 후 복학하는 경우 전역증 등의 증빙서류를 첨부하여 제출)* 복 신청 후 복학이 완료되기까지 3~4일 정도가 소요되오니, 수강신청을 위하여 꼭\xa0학적변동 기간 내에 복학신청을 완료하여주시기 바랍니다."},
#  {'title': '학사)휴학은 어떻게 신청하나요?',
# ...
